# %% [markdown]
# # EMD algorithm - Parameter experiments with a single trip
#
# ## Maria Inês Silva
# ## 13/01/2019
#
# ***

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle

# extendedMD code
import sys
import os
sys.path.insert(0, os.path.abspath('../'))
from extendedMD.motif_viz import create_motif_table, plot_k_motifs

# %%
cwd = os.getcwd()
input_folder = os.path.abspath(os.path.join(cwd, os.pardir, 'outputs/experiments_v2'))

# %%
def load_motif_data(folder):
    ts_1d = pickle.load(open(os.path.join(folder, "ts_1d.p"), "rb"))
    mdl_cost_list = pickle.load(open(os.path.join(folder, "mdl_cost.p"), "rb"))
    motif_point_list = pickle.load(open(os.path.join(folder, "motif_point.p"), "rb"))
    motif_center_list = pickle.load(open(os.path.join(folder, "motif_center.p"), "rb"))
    pattern_list = pickle.load(open(os.path.join(folder, "patterns.p"), "rb"))
    mean_dist = pickle.load(open(os.path.join(folder, "mean_dist.p"), "rb"))
    return ts_1d, mdl_cost_list, motif_point_list, motif_center_list, pattern_list, mean_dist

# %% [markdown]
# ***
#
# ## Experiment 1: Standard approach

# %%
folder = os.path.join(input_folder, 'trip_exp1')
ts_1d, mdl_cost_list, motif_point_list, motif_center_list, pattern_list, mean_dist = load_motif_data(folder)
df1 = create_motif_table(pattern_list, motif_point_list, mdl_cost_list, mean_dist)
df1.head(10)
# Out:
#     pattern  pattern_len  n_members  overlap_ratio  mdl_cost  mean_dist
# 115  [bccc]            1        104       0.080268   60820.6   0.043603
# 302  [cccd]            1        102       0.082413   61457.0   0.046667
# 162  [cccc]            1        173       0.371185   61742.7   0.041833
# 246  [ccbb]            1         88       0.094854   61889.3   0.048537
# 257  [ccdc]            1         88       0.064579   62015.5   0.046816
# 32   [cbbc]            1         80       0.044681   62209.0   0.048694
# 7    [cbcc]            1         95       0.096896   62366.4   0.047667
# 200  [bbcc]            1         88       0.051506   62407.2   0.049742
# 359  [cbbb]            1         84       0.098517   62521.6   0.053368
# 119  [ccdd]            1         82       0.067708   62635.9   0.048074

# %%
df1.plot.scatter('mdl_cost', 'mean_dist')
plt.show()

# %%
plot_k_motifs(5, ts_1d, mdl_cost_list, motif_point_list, motif_center_list, pattern_list)
# Out:
# 'Plot completed'

# %% [markdown]
# ***
#
# ## Experiment 2: Reduce window and PAA size

# %%
folder = os.path.join(input_folder, 'trip_exp2')
ts_1d, mdl_cost_list, motif_point_list, motif_center_list, pattern_list, mean_dist = load_motif_data(folder)
df2 = create_motif_table(pattern_list, motif_point_list, mdl_cost_list, mean_dist)
df2.head(10)
# Out:
#     pattern  pattern_len  n_members  overlap_ratio  mdl_cost  mean_dist
# 10    [ccc]            1        306       0.306496   51525.7   0.041106
# 98    [dcc]            1        189       0.084330   51658.9   0.044531
# 30    [ccd]            1        187       0.077061   51732.2   0.045299
# 106   [bcc]            1        188       0.079976   51865.8   0.044092
# 6     [cbb]            1        181       0.088761   52138.2   0.048010
# 8     [ccb]            1        182       0.065375   52338.2   0.046036
# 115   [bbc]            1        182       0.079674   52353.5   0.047413
# 5     [ddc]            1        145       0.037037   52564.5   0.044731
# 12    [cdd]            1        155       0.081218   52854.7   0.044920
# 20    [cdc]            1        165       0.092877   53146.0   0.041190

# %%
df2.plot.scatter('mdl_cost', 'mean_dist')
plt.show()

# %%
plot_k_motifs(5, ts_1d, mdl_cost_list, motif_point_list, motif_center_list, pattern_list)
# Out:
# 'Plot completed'

# %% [markdown]
# ***
#
# ## Experiment 3: Reduce window and PAA size and increase R

# %%
folder = os.path.join(input_folder, 'trip_exp3')
ts_1d, mdl_cost_list, motif_point_list, motif_center_list, pattern_list, mean_dist = load_motif_data(folder)
df3 = create_motif_table(pattern_list, motif_point_list, mdl_cost_list, mean_dist)
df3.head(10)
# Out:
#     pattern  pattern_len  n_members  overlap_ratio  mdl_cost  mean_dist
# 10    [ccc]            1        306       0.306496   51525.7   0.041106
# 98    [dcc]            1        189       0.084330   51658.9   0.044531
# 30    [ccd]            1        187       0.077061   51732.2   0.045299
# 106   [bcc]            1        188       0.079976   51865.8   0.044092
# 6     [cbb]            1        181       0.088761   52138.2   0.048010
# 8     [ccb]            1        182       0.065375   52338.2   0.046036
# 115   [bbc]            1        182       0.079674   52353.5   0.047413
# 5     [ddc]            1        145       0.037037   52564.5   0.044731
# 12    [cdd]            1        155       0.081218   52854.7   0.044920
# 20    [cdc]            1        165       0.092877   53146.0   0.041190

# %%
df3.plot.scatter('mdl_cost', 'mean_dist')
plt.show()

# %%
plot_k_motifs(5, ts_1d, mdl_cost_list, motif_point_list, motif_center_list, pattern_list)
# Out:
# 'Plot completed'
