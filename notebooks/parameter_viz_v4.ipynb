# %% [markdown]
# # EMD algorithm - Parameter experiments with a single trip
#
# ## Maria Inês Silva
# ## 29/01/2019
#
# ***

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle

# extendedMD code
import sys
import os
sys.path.insert(0, os.path.abspath('../'))
from extendedMD.motif_viz import create_motif_table, plot_k_motifs, plot_k_multdim_motifs

# %%
cwd = os.getcwd()
data_folder = os.path.abspath(os.path.join(cwd, os.pardir, 'data'))
output_folder = os.path.abspath(os.path.join(cwd, os.pardir, 'outputs/experiments_v4'))

# %%
def load_motif_data(folder):
    ts_1d = pickle.load(open(os.path.join(folder, "ts_1d.p"), "rb"))
    mdl_cost_list = pickle.load(open(os.path.join(folder, "mdl_cost.p"), "rb"))
    motif_point_list = pickle.load(open(os.path.join(folder, "motif_point.p"), "rb"))
    motif_center_list = pickle.load(open(os.path.join(folder, "motif_center.p"), "rb"))
    pattern_list = pickle.load(open(os.path.join(folder, "patterns.p"), "rb"))
    mean_dist = pickle.load(open(os.path.join(folder, "mean_dist.p"), "rb"))
    return ts_1d, mdl_cost_list, motif_point_list, motif_center_list, pattern_list, mean_dist

def load_ts_data(folder):
    trip_df = pd.read_pickle(os.path.join(folder, 'trip_df.pkl'))
    multi_dim_ts = trip_df[['ay', 'az']]
    events_ts = trip_df['event_type']
    return multi_dim_ts, events_ts

# %%
ts, events_ts = load_ts_data(data_folder)

# %% [markdown]
# ***
#
# ## Experiment 1: Lateral acceleration with adaptive break-points in the SAX transformation

# %%
folder = os.path.join(output_folder, 'trip_exp1')
ts_1d, mdl_cost_list, motif_point_list, motif_center_list, pattern_list, mean_dist = load_motif_data(folder)
df1 = create_motif_table(pattern_list, motif_point_list, mdl_cost_list, mean_dist)
df1.head(10)
# Out:
#    pattern  pattern_len  n_members  mdl_cost  mean_dist
# 50   [bdc]            1        240   47472.5   0.178033
# 26   [cbd]            1        235   47771.4   0.117668
# 21   [bcd]            1        212   48641.1   0.111195
# 16   [dbc]            1        220   48724.4   0.097910
# 44   [cdb]            1        215   49101.1   0.110176
# 30   [dcb]            1        211   49307.3   0.165575
# 40   [ccc]            1        197   50356.5   0.146100
# 4    [bbe]            1        178   50591.0   0.113258
# 45   [dda]            1        165   50634.6   0.113724
# 39   [add]            1        176   50677.8   0.118043

# %%
df1.plot.scatter('mdl_cost', 'mean_dist')
plt.show()

# %%
plot_k_motifs(5, ts_1d, events_ts, mdl_cost_list, motif_point_list, motif_center_list, pattern_list, 'lateral acc')
# Out:
# 'Plot completed'

# %% [markdown]
# ***
#
# ## Experiment 2: Longitudinal acceleration with adaptive break-points in the SAX transformation

# %%
folder = os.path.join(output_folder, 'trip_exp2')
ts_1d, mdl_cost_list, motif_point_list, motif_center_list, pattern_list, mean_dist = load_motif_data(folder)
df2 = create_motif_table(pattern_list, motif_point_list, mdl_cost_list, mean_dist)
df2.head(10)
# Out:
#    pattern  pattern_len  n_members  mdl_cost  mean_dist
# 37   [ccc]            1        192   38883.9   0.200480
# 28   [dcb]            1        167   43010.9   0.111164
# 42   [dda]            1        152   43127.9   0.097744
# 38   [ebb]            1        145   44108.7   0.132398
# 9    [eca]            1        129   44542.7   0.135165
# 35   [add]            1        134   44552.4   0.106171
# 4    [bbe]            1        130   44936.6   0.122916
# 36   [ace]            1        120   45586.2   0.109559
# 41   [cdb]            1        136   45908.7   0.093491
# 15   [dbc]            1        136   46138.4   0.147495

# %%
df2.plot.scatter('mdl_cost', 'mean_dist')
plt.show()

# %%
plot_k_motifs(5, ts_1d, events_ts, mdl_cost_list, motif_point_list, motif_center_list, pattern_list, 'longitudinal acc')
# Out:
# 'Plot completed'

# %% [markdown]
# ***
#
# ## Experiment 3: Lateral acceleration with fixed break-points in the SAX transformation

# %%
folder = os.path.join(output_folder, 'trip_exp3')
ts_1d, mdl_cost_list, motif_point_list, motif_center_list, pattern_list, mean_dist = load_motif_data(folder)
df3 = create_motif_table(pattern_list, motif_point_list, mdl_cost_list, mean_dist)
df3.head(10)
# Out:
#     pattern  pattern_len  n_members  mdl_cost  mean_dist
# 191   [ddd]            1         84   58047.8   0.057781
# 18    [dcc]            1         79   58178.4   0.059789
# 206   [cdd]            1         90   58202.5   0.060950
# 55    [ddc]            1         81   58343.2   0.062250
# 236   [ccd]            1         81   58352.5   0.060179
# 194   [edc]            1         70   58384.9   0.068728
# 1     [ded]            1         73   59038.5   0.057771
# 94    [dcd]            1         73   59274.8   0.059403
# 64    [edd]            1         72   59414.4   0.060525
# 170   [ccc]            1         73   59445.5   0.058475

# %%
df3.plot.scatter('mdl_cost', 'mean_dist')
plt.show()

# %%
plot_k_motifs(5, ts_1d, events_ts, mdl_cost_list, motif_point_list, motif_center_list, pattern_list, 'lateral acc')
# Out:
# 'Plot completed'

# %% [markdown]
# ***
#
# ## Experiment 4: Longitudinal acceleration with fixed break-points in the SAX transformation

# %%
folder = os.path.join(output_folder, 'trip_exp4')
ts_1d, mdl_cost_list, motif_point_list, motif_center_list, pattern_list, mean_dist = load_motif_data(folder)
df4 = create_motif_table(pattern_list, motif_point_list, mdl_cost_list, mean_dist)
df4.head(10)
# Out:
#     pattern  pattern_len  n_members  mdl_cost  mean_dist
# 36    [edd]            1         80   50796.8   0.038827
# 30    [ddc]            1         72   52564.8   0.038579
# 10    [dcc]            1         64   53828.6   0.036405
# 95    [eed]            1         67   54290.7   0.035127
# 107   [ccc]            1         58   55836.6   0.035479
# 120   [ddd]            1         67   56164.9   0.036068
# 173   [ffe]            1         52   56384.9   0.043004
# 124   [fed]            1         48   56649.3   0.048628
# 122   [edc]            1         52   56962.4   0.043622
# 23    [eee]            1         57   57009.2   0.035840

# %%
df4.plot.scatter('mdl_cost', 'mean_dist')
plt.show()

# %%
plot_k_motifs(5, ts_1d, events_ts, mdl_cost_list, motif_point_list, motif_center_list, pattern_list, 'longitudinal acc')
# Out:
# 'Plot completed'
